# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math
from random import random

# %%
df = pd.read_csv("SpotifyData.csv")
grouped = df.groupby('year').apply(lambda x: x.sort_values(['year'], ascending=True))
df['year'].value_counts()
# Out:
# 2012    115
# 2017    111
# 2001    108
# 2018    107
# 2010    107
# 2014    104
# 2005    104
# 2011     99
# 2016     99
# 2015     99
# 2003     97
# 2008     97
# 2004     96
# 2006     95
# 2007     94
# 2002     90
# 2019     89
# 2013     89
# 2009     84
# 2000     74
# 1999     38
# 2020      3
# 1998      1
# Name: year, dtype: int64

# %%
# group the data frame by the 'year' column and sort the groups based on the values in that column
grouped = df.groupby('year').apply(lambda x: x.sort_values(['year'], ascending=True))

# reset the index of the resulting data frame
grouped = grouped.reset_index(drop=True)

print(grouped)
# Out:
#                      artist                                            song  \
# 0             Missy Elliott                                        Hot Boyz
# 1                 blink-182                            All The Small Things
# 2              Donell Jones  U Know What's Up (feat. Lisa "Left Eye" Lopes)
# 3        Christina Aguilera                                   I Turn to You
# 4     Red Hot Chili Peppers                                       Otherside
# ...                     ...                                             ...
# 1995               Anuel AA                                           China
# 1996            Post Malone                                         Circles
# 1997               t.A.T.u.                         All The Things She Said
# 1998             Will Smith                                          Switch
# 1999                    NSG                                         Options
#
#       duration  year  popularity  danceability  energy  key  loudness  mode  \
# 0       215466  1998          49         0.727   0.445    1   -11.241     1
# 1       167066  1999          79         0.434   0.897    0    -4.918     1
# 2       243733  1999          63         0.854   0.543    8    -6.166     0
# 3       273706  1999          61         0.599   0.470    1    -8.356     1
# 4       255373  1999          78         0.458   0.795    0    -3.265     1
# ...        ...   ...         ...           ...     ...  ...       ...   ...
# 1995    301714  2019          76         0.786   0.808    7    -3.702     1
# 1996    215280  2019          85         0.695   0.762    0    -3.497     1
# 1997    214440  2020          39         0.527   0.834    5    -5.767     0
# 1998    197666  2020          34         0.873   0.900    5    -4.325     0
# 1999    240081  2020          57         0.836   0.621    1    -4.684     0
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo
# 0          0.2910       0.33900          0.000000    0.1800    0.527   81.125
# 1          0.0488       0.01030          0.000000    0.6120    0.684  148.726
# 2          0.0844       0.04020          0.000057    0.0419    0.868  103.032
# 3          0.0376       0.38000          0.000000    0.1110    0.298  127.177
# 4          0.0574       0.00316          0.000202    0.0756    0.513  123.229
# ...           ...           ...               ...       ...      ...      ...
# 1995       0.0882       0.08460          0.000289    0.0822    0.609  105.027
# 1996       0.0395       0.19200          0.002440    0.0863    0.553  120.042
# 1997       0.0474       0.04110          0.005990    0.1050    0.381  179.920
# 1998       0.1800       0.01070          0.000502    0.5560    0.478  102.516
# 1999       0.0894       0.38900          0.000092    0.1040    0.762  101.993
#
# [2000 rows x 16 columns]

# %%
#Drop Instrumentalness, acousticness, speechness, key, mode, danceability
grouped.drop(['instrumentalness', 'acousticness', 'speechiness', 'key', 'mode', 'danceability', "artist", "song", "liveness"], axis = 1, inplace=True)
grouped.dropna(axis=0, inplace=True)
grouped['duration'] = df['duration'] / 1000
grouped= grouped[grouped['popularity']>20]
grouped.describe()
# Out:
#           duration         year   popularity       energy     loudness  \
# count  1816.000000  1816.000000  1816.000000  1816.000000  1816.000000
# mean    229.131965  2009.201542    65.846916     0.721867    -5.495205
# std      39.753895     5.889536    10.607587     0.152242     1.944991
# min     113.000000  1998.000000    21.000000     0.054900   -20.514000
# 25%     204.143250  2004.000000    59.000000     0.625000    -6.483250
# 50%     223.504500  2009.000000    67.000000     0.737500    -5.270000
# 75%     249.036000  2014.000000    74.000000     0.840250    -4.145500
# max     484.146000  2020.000000    89.000000     0.999000    -0.276000
#
#            valence        tempo
# count  1816.000000  1816.000000
# mean      0.553893   120.158735
# std       0.220435    27.187386
# min       0.040600    60.019000
# 25%       0.392750    98.040000
# 50%       0.560000   120.018000
# 75%       0.733000   135.096000
# max       0.973000   210.851000

# %%
#Data Normalization: Min-Max scaling
#This turns all the values into a number between 0 and 1

# copy the data
dfmms = grouped.copy()
  
# apply normalization techniques
for column in dfmms.columns:
    dfmms[column] = (dfmms[column] - dfmms[column].min()) / (dfmms[column].max() - dfmms[column].min())    
  
# view normalized data
print(dfmms)
dfmms.describe()
# Out:
#       duration      year  popularity    energy  loudness   valence     tempo
# 0     0.264478  0.000000    0.411765  0.413198  0.458197  0.521665  0.139931
# 1     0.145673  0.045455    0.852941  0.891961  0.770630  0.690047  0.588118
# 2     0.370598  0.045455    0.617647  0.517000  0.708963  0.887387  0.285172
# 3     0.300402  0.045455    0.588235  0.439678  0.600751  0.276062  0.445250
# 4     0.235918  0.045455    0.838235  0.783921  0.852308  0.506650  0.419076
# ...        ...       ...         ...       ...       ...       ...       ...
# 1995  0.183286  0.954545    0.808824  0.797691  0.830714  0.609610  0.298398
# 1996  0.176281  0.954545    0.941176  0.748967  0.840844  0.549550  0.397946
# 1997  0.236007  1.000000    0.264706  0.825230  0.728679  0.365079  0.794931
# 1998  0.156351  1.000000    0.191176  0.895138  0.799931  0.469112  0.281751
# 1999  0.275579  1.000000    0.529412  0.599619  0.782192  0.773702  0.278283
#
# [1816 rows x 7 columns]
#           duration         year   popularity       energy     loudness  \
# count  1816.000000  1816.000000  1816.000000  1816.000000  1816.000000
# mean      0.312901     0.509161     0.659513     0.706458     0.742109
# std       0.107111     0.267706     0.155994     0.161257     0.096106
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.245572     0.272727     0.558824     0.603856     0.693287
# 50%       0.297739     0.500000     0.676471     0.723017     0.753236
# 75%       0.366530     0.727273     0.779412     0.831850     0.808800
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#            valence        tempo
# count  1816.000000  1816.000000
# mean      0.550507     0.398720
# std       0.236416     0.180249
# min       0.000000     0.000000
# 25%       0.377681     0.252075
# 50%       0.557057     0.397787
# 75%       0.742600     0.497752
# max       1.000000     1.000000

# %%
cor = dfmms.corr()
print(cor)
plt.figure(figsize= (15,10))
sns.heatmap(cor, annot=True)
# Out:
#             duration      year  popularity    energy  loudness   valence  \
# duration    1.000000 -0.305924   -0.059964  0.071727  0.012613  0.129276
# year       -0.305924  1.000000    0.299172 -0.115790  0.017051 -0.218760
# popularity -0.059964  0.299172    1.000000 -0.088780  0.013715 -0.098181
# energy      0.071727 -0.115790   -0.088780  1.000000  0.654013  0.333432
# loudness    0.012613  0.017051    0.013715  0.654013  1.000000  0.225632
# valence     0.129276 -0.218760   -0.098181  0.333432  0.225632  1.000000
# tempo      -0.023231  0.069409    0.024903  0.154186  0.078457 -0.037336
#
#                tempo
# duration   -0.023231
# year        0.069409
# popularity  0.024903
# energy      0.154186
# loudness    0.078457
# valence    -0.037336
# tempo       1.000000
# <Axes: >

# %%
# Test/Train Split
length = len(grouped.index)
split = int(length * 0.7)
train = grouped[0:split]
test = grouped[split:length]

print(train)
# Out:
#       duration  year  popularity  energy  loudness  valence    tempo
# 0      211.160  1998          49   0.445   -11.241    0.527   81.125
# 1      167.066  1999          79   0.897    -4.918    0.684  148.726
# 2      250.546  1999          63   0.543    -6.166    0.868  103.032
# 3      224.493  1999          61   0.470    -8.356    0.298  127.177
# 4      200.560  1999          78   0.795    -3.265    0.513  123.229
# ...        ...   ...         ...     ...       ...      ...      ...
# 1355   259.102  2013          77   0.428    -9.504    0.337   84.878
# 1356   174.853  2013          64   0.706    -6.849    0.238  179.911
# 1357   226.986  2013          74   0.727    -5.456    0.521  121.985
# 1358   150.400  2013          75   0.695    -4.782    0.302  169.533
# 1359   212.560  2013          62   0.796    -3.446    0.282  128.954
#
# [1271 rows x 7 columns]

# %%
# Helper functions
def take_random_step(model):
  return [
      model[0] + (random() - 0.5), # Subtract off 0.5 to generate negative and positive steps
      model[1] + (random() - 0.5),
      model[2] + (random() - 0.5),
      model[3] + (random() - 0.5),
      model[4] + (random() - 0.5),
      model[5] + (random() - 0.5),
      model[6] + (random() - 0.5),
      model[7] + (random() - 0.5)
  ]

def take_best_step(trainDF, model):
  old_distance = calculateDistance(trainDF, model)
  for i in range(50): # try 50 times; if we fail to improve, return the old model
    new_model = take_random_step(model)
    new_distance = calculateDistance(trainDF, new_model)
    if new_distance < old_distance:
      return new_model
  return model # by default, return the old model

def calculateDistance(trainDF, model):
  sum = 0
  for i in range(len(trainDF.index[:10])):
    # Get data points
    duration = trainDF.iat[i, 0]
    year = trainDF.iat[i, 1]
    popularity = trainDF.iat[i,2]
    energy = trainDF.iat[i, 3]
    loudness = trainDF.iat[i, 4]
    valence = trainDF.iat[i, 5]   
    tempo = trainDF.iat[i, 6]

    # Get coefficients
    a = model[0]
    b = model[1]
    c = model[2]
    d = model[3]
    e = model[4]
    f = model[5]
    g = model[6] 
    h = model[7]

    # Calculate distance using formula: https://i.ytimg.com/vi/zWMTTRJ0l4w/maxresdefault.jpg
    numerator = abs((a * duration) + (b * year) + (c * popularity) + (d * loudness) + (e * energy) + (f * valence) + (g * tempo) + h)
    denominator = math.sqrt((a * a) + (b * b) + (c * c ) + (d * d) + (e * e) + (f * f) + (g * g) + (h * h))
    distance = numerator / denominator
    sum = sum + distance
 
  return sum

# %%
def trainMRModel(trainDF, iterations):
  
  # Initialize naive model A
  modelA = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5] # [a, b, c, d]

  distanceA = calculateDistance(trainDF, modelA)
  print("First model - weights: ", modelA, " distance: ", distanceA)
  
  modelB = modelA[:] # make a copy of model A -> 'modelB = modelA' just references original model A
  
  # Randomly take steps for desired iterations
  for i in range(iterations):
    modelB = take_best_step(trainDF, modelB)
  
  # Calculate distance of best model found
  distanceB = calculateDistance(trainDF, modelB)
  print("Final model - weights: ", modelB, " distance: ", distanceB)
  return modelB

# %%
weights = trainMRModel(train, 100)
print(weights)
# Out:
# First model - weights:  [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]  distance:  8523.598783604288
# Final model - weights:  [0.5049929518210586, -0.15158392401602827, 2.1840305811911307, 1.6319732803502935, 2.04538352402506, 0.2827341817563651, 0.4134375580645536, 0.9566254593247131]  distance:  42.213663560533135
# [0.5049929518210586, -0.15158392401602827, 2.1840305811911307, 1.6319732803502935, 2.04538352402506, 0.2827341817563651, 0.4134375580645536, 0.9566254593247131]

# %%
for i in range(len(weights)):
    a = weights[0]
    b = weights[1]
    c = weights[2]
    d = weights[3]
    e = weights[4]
    f = weights[5]
    g = weights[6]
    h = weights[7]

print(a)

prediction = []
#ax +by = c
for row in range(0, len(test.index)):
    duration = test.iat[i, 0]
    year = test.iat[i, 1]
    popularity = test.iat[i,2]
    energy = test.iat[i, 3]
    loudness = test.iat[i, 4]
    valence = test.iat[i, 5]   
    tempo = test.iat[i, 6]
    prediction.append((h - (a * duration) - ( b*year ) - (d * loudness)- (e * energy ) - (f * valence ) - (g * tempo ))/ c)
#print(test['popularity'])
print(prediction)
# Out:
# 0.5049929518210586
# [60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.43370783183342, 60.433707 ...

# %%
actual = [row for row in test.iloc[:, 2]]
print(actual)
# Out:
# [39, 48, 47, 55, 56, 74, 76, 66, 84, 66, 71, 68, 66, 72, 54, 69, 75, 84, 79, 68, 89, 57, 53, 80, 66, 55, 75, 70, 63, 72, 80, 64, 70, 52, 83, 79, 74, 74, 65, 58, 79, 49, 73, 61, 69, 61, 67, 77, 81, 74, 69, 66, 80, 78, 79, 33, 65, 63, 69, 82, 75, 78, 76, 81, 53, 62, 85, 67, 77, 66, 72, 54, 72, 71, 45, 69, 67, 74, 67, 61, 50, 78, 80, 80, 79, 69, 79, 70, 68, 49, 66, 66, 75, 74, 72, 73, 48, 59, 72, 66, 68, 70, 64, 80, 77, 62, 78, 76, 21, 73, 62